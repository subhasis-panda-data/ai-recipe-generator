# %%
import os
from dotenv import load_dotenv

# Load the environment variables
load_dotenv()

# Access them using standard os.environ
api_key = os.getenv("API_KEY")

# %%
from google import genai

client = genai.Client(api_key=api_key)

response = client.models.generate_content(
    model="gemini-3.5-flash",
    contents="Importance of LLM in current 2026 in 2lines"
)
print(response.text)
# Out:
# In 2026, LLMs have transitioned from passive assistants into autonomous agents that drive complex decision-making, scientific breakthroughs, and global industrial workflows.
# They now serve as the essential cognitive infrastructure of society, seamlessly translating human intent into highly efficient, automated execution.

# %%
def generate_receipe(ingredients,cuisine,diet):
    '''
    Generate a receipe using ingredients provided.
    cuisine can be "Italian","Indian","Mexican","Any" etc.
    diet can be "Vegan","Vegeterian","Jain",etc.
    '''
    prompt = f'''
    Generate one food receipe using these ingredients:{','.join(ingredients)}
    Receipe should not be more than 100 words
    Cuisine: {cuisine}
    Diet: {diet}
    '''
    response = client.models.generate_content(
    model="gemini-3.5-flash",
    contents=prompt
    )
    return response.text

# %%
receipe = generate_receipe(["tomatoes","jeera","salt","lentils","oil","onion"],"Indian","Vegan")
print(receipe)
# Out:
# **Simple Indian Tomato Dal**
#
# * **Ingredients:** ½ cup lentils, 1 tbsp oil, 1 tsp jeera (cumin seeds), 1 chopped onion, 2 chopped tomatoes, salt.
#
# * **Instructions:**
# 1. Boil lentils in 2 cups of water with salt until soft. Set aside.
# 2. Heat oil in a pan. Add jeera and let them splutter.
# 3. Add chopped onion and sauté until translucent.
# 4. Stir in tomatoes and cook until mushy.
# 5. Pour the boiled lentils into the pan.
# 6. Mix well, adjust salt, and simmer for 5 minutes.
#
# Serve hot with rice.
